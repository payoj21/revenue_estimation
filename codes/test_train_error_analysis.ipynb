# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy

# %%
train_df = pd.read_csv(r"C:\Users\payoj.jain/Documents/projects/Europe Revenue estimation/models/catboost_info/learn_error.tsv",delimiter="\t")
test_df = pd.read_csv(r"C:\Users\payoj.jain/Documents/projects/Europe Revenue estimation/models/catboost_info/test_error.tsv",delimiter="\t")

# %%
train_df.head()
# Out:
#    iter      RMSE
# 0     0  0.387267
# 1     1  0.384310
# 2     2  0.381515
# 3     3  0.378874
# 4     4  0.376343

# %%
plt.figure(figsize=(20,5))
plt.plot(train_df["iter"], train_df["RMSE"], label="train_error")
plt.plot(test_df["iter"], test_df["RMSE"], label="test_error")
plt.xlim(0,1500)
plt.legend()
plt.show()
